# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.sin(X), np.cos(X)
# print(C, S, sep='\n')
line1, line2= plt.plot(X, C, 'r', X, S)
# plt.plot(X, S)
line1.set_antialiased(False)
plt.show()
